# %%
import time
import pandas as pd
import numpy as np

CITY_DATA = { 'chicago': 'chicago.csv',
              'new york city': 'new_york_city.csv',
              'washington': 'washington.csv' }

def get_filters():

    print('Hello! Let\'s explore some US bikeshare data!')
    
    city = input('enter the city: ').lower()
    while city not in CITY_DATA.keys():
        city = input('enter the city: ').lower()
    month = input('enter the month or all for all months: ')
    day = input('enter the day or all for all days: ')
    
    print('-'*40)
    return city, month, day

# exceptions to be considered

# %%
def load_data(city, month, day):
    """
    Loads data for the specified city and filters by month and day if applicable.

    Args:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    Returns:
        df - Pandas DataFrame containing city data filtered by month and day
    """
    df = pd.read_csv(CITY_DATA[city])
    df['Start Time'] = pd.to_datetime(df['Start Time'])
    df['month'] = df['Start Time'].dt.month
    df['day_of_week'] = df['Start Time'].dt.day_name()
    df['hour'] = df['Start Time'].dt.hour

    if month != 'all':
        months = ['january', 'february', 'march', 'april', 'may', 'june']
        month = months.index(month) + 1
        
        df = df[df['month'] == month]

    if day != 'all':
        df = df[df['day_of_week'] == day.title()]

    return df

# %%
def time_stats(df):
    """Displays statistics on the most frequent times of travel."""

    print('\nCalculating The Most Frequent Times of Travel...\n')
    start_time = time.time()

    # TO DO: display the most common month
    print('the most common month: ',df.month.mode()[0])

    # TO DO: display the most common day of week
    print('the most common day of the week: ',df.day_of_week.mode()[0])

    # TO DO: display the most common start hour
    print('the most common start hour: ',df.hour.mode()[0])

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

# %%
def station_stats(df):
    """Displays statistics on the most popular stations and trip."""

    print('\nCalculating The Most Popular Stations and Trip...\n')
    start_time = time.time()

    # TO DO: display most commonly used start station
    print('the most commonly start starion: ',df['Start Station'].mode()[0])

    # TO DO: display most commonly used end station
    print('the most commonly end starion: ',df['End Station'].mode()[0])

    # TO DO: display most frequent combination of start station and end station trip
    print('the most frequent combination is: {} and {} '.format(
    df.groupby(['Start Station','End Station'])[['Start Station','End Station']].count().idxmax().values[0][0],
    df.groupby(['Start Station','End Station'])[['Start Station','End Station']].count().idxmax().values[0][1]))

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

# %%
def trip_duration_stats(df):
    """Displays statistics on the total and average trip duration."""

    print('\nCalculating Trip Duration...\n')
    start_time = time.time()

    # TO DO: display total travel time
    print('total travel time: ', df['Trip Duration'].sum())

    # TO DO: display mean travel time
    print('mean travel time: ', df['Trip Duration'].mean())

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

# %%
def user_stats(df,city):
    """Displays statistics on bikeshare users."""

    print('\nCalculating User Stats...\n')
    start_time = time.time()

    # TO DO: Display counts of user types
    print('counts of user types \n', dict(df.groupby(['User Type'])['User Type'].count()))
    if city != 'washington':
        # TO DO: Display counts of gender
        print('counts of gender \n', dict(df.groupby(['Gender'])['Gender'].count()))

        # TO DO: Display earliest, most recent, and most common year of birth
        print('the earliest year of birth is: {} , the most recent is: {} , the most common is: {}'.format(
        df['Birth Year'].min(), df['Birth Year'].max(), df['Birth Year'].mode()[0]))

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

# %%
def display_data(df):
    user_input = input('Do you want to see the first 5 rows of data? enter yes or no? ').lower()
    r1=0
    r2=5
    while user_input == 'yes':
        print(df.iloc[r1:r2,:])
        r1=r2
        r2+=5
        user_input = input('Do you want to see the first 5 rows of data? enter yes or no? ').lower()
        if user_input == 'yes':
            continue
        elif user_input == 'no':
            break

# %%
def main():
    while True:
        city, month, day = get_filters()
        df = load_data(city, month, day)

        time_stats(df)
        station_stats(df)
        trip_duration_stats(df)
        user_stats(df,city)
        display_data(df)

        restart = input('\nWould you like to restart? Enter yes or no.\n')
        if restart.lower() != 'yes':
            break


if __name__ == "__main__":
    main()
# Out:
# Hello! Let's explore some US bikeshare data!
# enter the city: chicago
# enter the month or all for all months: march
# enter the day or all for all days: all
# ----------------------------------------
#
# Calculating The Most Frequent Times of Travel...
#
# the most common month:  3
# the most common day of the week:  Friday
# the most common start hour:  17
#
# This took 0.0 seconds.
# ----------------------------------------
#
# Calculating The Most Popular Stations and Trip...
#
# the most commonly start starion:  Clinton St & Washington Blvd
# the most commonly end starion:  Clinton St & Washington Blvd
# the most frequent combination is: Calumet Ave & 33rd St and State St & 33rd St
#
# This took 0.03151392936706543 seconds.
# ----------------------------------------
#
# Calculating Trip Duration...
#
# total travel time:  20972420
# mean travel time:  707.5953979553966
#
# This took 0.0 seconds.
# ----------------------------------------
#
# Calculating User Stats...
#
# ...
